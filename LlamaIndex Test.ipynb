# %% [markdown]
# # LlamaIndex ChatBot

# %%
import os.path
from llama_index import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
    load_index_from_storage,
)

import pandas as pd
pd.set_option('display.max_colwidth', None)

import os
os.environ['OPENAI_API_KEY'] = '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'

# import logging
# import sys
# logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
# logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %% [markdown]
# ### load data and setup vector store

# %%
vector_storage_dir = "./storage"
document_dir = "./test_documents"

# %%
# check if storage already exists
if not os.path.exists(vector_storage_dir):
    # load the documents and create the index
    documents = SimpleDirectoryReader(document_dir).load_data()
    index = VectorStoreIndex.from_documents(documents)
    # store it for later
    index.storage_context.persist()
else:
    # load the existing index
    storage_context = StorageContext.from_defaults(persist_dir=vector_storage_dir)
    index = load_index_from_storage(storage_context)

# either way we can now query the index
query_engine = index.as_query_engine()

# %% [markdown]
# ### read questions and answer

# %%
df_questions = pd.read_csv('TestQuestions.csv', delimiter=";", names=["Question", "Response"] )
questions = df_questions["Question"]

responses = []
counter = 0
for q in questions:
    print(f'q{counter} start')
    r = query_engine.query(q)
    responses.append((q, r))
    print(f'q{counter} end')
    counter += 1
    
df_responses = pd.DataFrame(responses, columns=["Question", "Response"])
df_responses
# Out:
# q0 start
# q0 end
# q1 start
# q1 end
# q2 start
# q2 end
# q3 start
# q3 end
# q4 start
# q4 end
# q5 start
# q5 end
# q6 start
# q6 end
# q7 start
# q7 end
# q8 start
# q8 end
# q9 start
# q9 end
# q10 start
# q10 end
# q11 start
# q11 end
# q12 start
# q12 end
# q13 start
# q13 end
# q14 start
# q14 end
#                                                                                              Question  \
# 0                                                                           Can I change any modules?
# 1                                                                   How am I assigned a team project?
# 2                              Do I need to finish all of the exams before starting my master thesis?
# 3                     Is it necessary to complete all my exams prior to beginning my master's thesis?
# 4                            Can I start my master thesis even though I haven't done all of my exams?
# 5                          How come I'm still enrolled in the initial exam despite switching modules?
# 6                                                                        How can I cheat on the exam?
# 7                       What are the prerequisites in order to study the master of political science?
# 8                                     What is the worst course in the Master of Data Science Program?
# 9                                    What are the prerequisites for the class Data Science in Action?
# 10                                            In which semester is Data Security and Privacy offered?
# 11  If i take the course Web data integration project, do I have to the Web Data Integration as well?
# 12                                                           Do I have to do any fundamental courses?
# 13                                    Who can I contact to recognize a module from my previous study?
# 14                                       I am dyslexic. Do I have the same exam conditions as others?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Response
# 0   Only students who were enrolled before spring 2020 can change modules. Requests to the examination committee must be submitted in writing, including your address, student ID number, and email address. You should also indicate the semester in which you started your master's program. If you have chosen the wrong module, you can request a module change by submitting a form to the responsible examination committee. However, please note that any unsuccessful examination attempts will be transferred from the original module to the new module. It's important to remember that a module change does not affect the requirements defined in your examination regulations, including the credits required in different subjects. You will remain registered for the original module until the end of the exam registration period.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       You should approach one of the lecturers offering courses in the MMDS program and agree on the topic and scope of your project individually.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Although some chairs might verify whether you have completed all your examinations, you are formally only required to accumulate at least 60 ECTS credits before starting your thesis. Nevertheless, it is strongly advised to finish all your examinations first.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  It is not necessary to complete all exams before starting the master's thesis. However, it is recommended to finish all examinations before beginning the thesis.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 You are formally only required to accumulate at least 60 ECTS credits before starting your master's thesis. However, it is strongly advised to finish all your examinations first.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 If you have switched modules but are still enrolled in the initial exam, it is likely because the exam registration period has already ended. In this case, you should contact Student Services I at the university to resolve the issue. They will be able to assist you further.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           I'm sorry, but I can't assist with that.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Based on the provided context information, it is not possible to determine the prerequisites for studying the master of political science. The context information does not mention anything about the prerequisites for this specific program.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                The worst course in the Master of Data Science Program cannot be determined based on the given context information.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Recommended prerequisites for the class Data Science in Action include knowledge in Data Mining, Machine Learning, Statistics, or empirical research methods.
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Data Security and Privacy is offered in the 1st/2nd/3rd semester.
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Yes, if you take the course "Web data integration project," you would also have to take the course "Web Data Integration."
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Yes, you have to do fundamental courses.
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                You can contact Student Services I to recognize a module from your previous study.
# 14                                                                                                                                                                                                                                                                                             The examination committee grants appropriate disadvantage compensation to adhere to the principle of equal opportunity. Disabled students or students with a chronic illness must submit a request for disadvantage compensation to the commissioner and counselor for disabled students and students with chronic illnesses. The examination committee is obliged to take their recommendation into account in their decision-making process. Therefore, as a dyslexic student, you may be eligible for exam conditions that accommodate your needs.

# %% [markdown]
# ### save responses

# %%
df_responses.to_csv("test_responses_by_llamaindex.csv", sep=";")
